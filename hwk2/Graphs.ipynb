# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.style.use('default')

# %%
res_hellinger = {
    "aeroplanes" :
    {
        10: 0.5405,
        50: 0.6444,
        100: 0.7072
    },
        "motorbikes" :
    {
        10: 0.3685,
        50: 0.5474,
        100: 0.6325
    },
        "persons" :
    {
        10: 0.6686,
        50: 0.7326,
        100: 0.7739
    }
}

Hel = np.array([
    [10, 0.5405, 0.3685, 0.6686],
    [50, 0.6444, 0.5474, 0.7326],
    [100, 0.7072, 0.6325, 0.7739]
])

# %%
res_natural = {
    "aeroplanes" :
    {
        10: 0.3277,
        50: 0.4050,
        100: 0.5495
    },
        "motorbikes" :
    {
        10: 0.2523,
        50: 0.3823,
        100: 0.4866
    },
        "persons" :
    {
        10: 0.5989,
        50: 0.6723,
        100: 0.7064
    }
}

Nat = np.array([
    [10, 0.3277, 0.2523, 0.5989],
    [50, 0.4050, 0.3823, 0.6723],
    [100, 0.5495, 0.4866, 0.7064]
])

Keys = ["aeroplanes", "motorbikes", "persons"]

# %%
Nat
# Out:
# array([[  10.    ,    0.3277,    0.2523,    0.5989],
#        [  50.    ,    0.405 ,    0.3823,    0.6723],
#        [ 100.    ,    0.5495,    0.4866,    0.7064]])

# %%
plt.figure(figsize = (10, 10))

for i in range(1, Nat.shape[1]):
    plt.plot(Nat[:, 0], Nat[:, i], label = Keys[i - 1])

plt.xlabel("Proportion of training images (in %)", fontsize = 20);
plt.ylabel("AP", fontsize = 20);
plt.xticks(fontsize=15);
plt.yticks(fontsize=15);
plt.legend(fontsize = 20);

# %%
plt.figure(figsize = (10, 10))

for i in range(1, Hel.shape[1]):
    plt.plot(Hel[:, 0], Hel[:, i], label = Keys[i - 1])

plt.xlabel("Proportion of training images (in %)", fontsize = 20);
plt.ylabel("AP", fontsize = 20);
plt.xticks(fontsize=15);
plt.yticks(fontsize=15);
plt.legend(fontsize = 20);
